# %%
from cashier import Transaction

# %%
user = Transaction()

# Test Case 1
# Add Item 1
print("Test Case 1")
print("-----------------------------------------------------------------------")
user.add_item("Ayam Goreng", 2, 20_000)
print("\n")
# Add Item 2
user.add_item("Pasta Gigi", 3, 15_000)
print("\n")
print("Tabel transaksi:")
user.check_order()


# Test Case 2
# Delete pasta gigi from order table
print("\n")
print("Test Case 2")
print("-----------------------------------------------------------------------")
user.delete_item("Pasta Gigi")
# Out:
# Test Case 1
# -----------------------------------------------------------------------
# Masukkan item yang akan dibeli
# Nama Item     : Ayam Goreng
# Jumlah Item   : 2
# Harga per-Item: Rp. 20000
#
#
# Masukkan item yang akan dibeli
# Nama Item     : Pasta Gigi
# Jumlah Item   : 3
# Harga per-Item: Rp. 15000
#
#
# Tabel transaksi:
# Pemesanan sudah benar
# +-------------+---------------+--------------+---------------+
# |  Nama Item  |   Jumlah Item |   Harga/Item |   Total Harga |
# |-------------+---------------+--------------+---------------|
# | Ayam Goreng |             2 |        20000 |         40000 |
# | Pasta Gigi  |             3 |        15000 |         45000 |
# +-------------+---------------+--------------+---------------+
#
#
# Test Case 2
# -----------------------------------------------------------------------
# Anda telah menghapus item Pasta Gigi dari transaksi
#
# +-------------+---------------+--------------+---------------+
# |  Nama Item  |   Jumlah Item |   Harga/Item |   Total Harga |
# |-------------+---------------+--------------+---------------|
# | Ayam Goreng |             2 |        20000 |         40000 |
# +-------------+---------------+--------------+---------------+

# %%
# Test Case 3
# Reset all transaction
print("\n")
print("Test Case 3")
print("-----------------------------------------------------------------------")
user.reset_transaction()
# Out:
# Test Case 3
# -----------------------------------------------------------------------
# Semua item berhasil di delete!
# +-------------+---------------+--------------+---------------+
# |  Nama Item  |  Jumlah Item  |  Harga/Item  |  Total Harga  |
# |-------------+---------------+--------------+---------------|
# +-------------+---------------+--------------+---------------+

# %%
# Test Case 4
# Total Transaction
user = Transaction()
print("\n")
print("Test Case 4")
print("-----------------------------------------------------------------------")
# Add Item 1
user.add_item("Ayam Goreng", 2, 20_000)
print("\n")
# Add Item 2
user.add_item("Pasta Gigi", 3, 15_000)
print("\n")
# Add Item 3
user.add_item("Mainan Mobil", 1, 200_000)
print("\n")
# Add Item 4
user.add_item("Mie Instan", 5, 3_000)
print("\n")
print("Tabel transaksi:")
user.check_order()
user.total_price()
# Out:
# Test Case 4
# -----------------------------------------------------------------------
# Masukkan item yang akan dibeli
# Nama Item     : Ayam Goreng
# Jumlah Item   : 2
# Harga per-Item: Rp. 20000
#
#
# Masukkan item yang akan dibeli
# Nama Item     : Pasta Gigi
# Jumlah Item   : 3
# Harga per-Item: Rp. 15000
#
#
# Masukkan item yang akan dibeli
# Nama Item     : Mainan Mobil
# Jumlah Item   : 1
# Harga per-Item: Rp. 200000
#
#
# Masukkan item yang akan dibeli
# Nama Item     : Mie Instan
# Jumlah Item   : 5
# Harga per-Item: Rp. 3000
#
#
# Tabel transaksi:
# Pemesanan sudah benar
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# |  Pasta Gigi  |             3 |        15000 |         45000 |
# | Mainan Mobil |             1 |       200000 |        200000 |
# |  Mie Instan  |             5 |         3000 |         15000 |
# +--------------+---------------+--------------+---------------+
# Total Harga item sebesar Rp.300000
# Anda mendapatkan diskon sebesar 5%
# Total pembayaran sebesar Rp.285000
# Terima kasih sudah berbelanja

# %%
# Test Case 5
# Update Item, Quantity, dan Harga
print("\n")
print("Test Case 5")
print("--------------------------------------------------------------------------")
print("Tabel Pemesanan Sebelum Update:")
user.check_order()
user.total_price()
print("\n")
# Update Item pasta gigi
user.update_item_name("Pasta Gigi", "Face Wash")
# Update Quantity mie instan
user.update_item_quantity("Mie Instan", 8)
# Update Harga mainan mobil
user.update_item_price("Mainan Mobil", 230_000)
print("\n")
print("Tabel Pemesanan Setelah Update:")
user.check_order()
user.total_price()
# Out:
# Test Case 5
# --------------------------------------------------------------------------
# Tabel Pemesanan Sebelum Update:
# Pemesanan sudah benar
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# |  Pasta Gigi  |             3 |        15000 |         45000 |
# | Mainan Mobil |             1 |       200000 |        200000 |
# |  Mie Instan  |             5 |         3000 |         15000 |
# +--------------+---------------+--------------+---------------+
# Total Harga item sebesar Rp.300000
# Anda mendapatkan diskon sebesar 5%
# Total pembayaran sebesar Rp.285000
# Terima kasih sudah berbelanja
#
#
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# | Mainan Mobil |             1 |       200000 |        200000 |
# |  Mie Instan  |             5 |         3000 |         15000 |
# |  Face Wash   |             3 |        15000 |         45000 |
# +--------------+---------------+--------------+---------------+
# Anda mengganti item Pasta Gigi menjadi Face Wash
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# | Mainan Mobil |             1 |       200000 |        200000 |
# |  Mie Instan  |             8 |         3000 |         24000 |
# |  Face Wash   |             3 |        15000 |         45000 |
# +--------------+---------------+--------------+---------------+
# Anda mengganti jumlah item Mie Instan menjadi 8
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# | Mainan Mobil |             1 |       230000 |        230000 |
# |  Mie Instan  |             8 |         3000 |         24000 |
# |  Face Wash   |             3 |        15000 |         45000 |
# +--------------+---------------+--------------+---------------+
# Anda mengganti jumlah item Mainan Mobil menjadi 230000
#
#
# Tabel Pemesanan Setelah Update:
# Pemesanan sudah benar
# +--------------+---------------+--------------+---------------+
# |  Nama Item   |   Jumlah Item |   Harga/Item |   Total Harga |
# |--------------+---------------+--------------+---------------|
# | Ayam Goreng  |             2 |        20000 |         40000 |
# | Mainan Mobil |             1 |       230000 |        230000 |
# |  Mie Instan  |             8 |         3000 |         24000 |
# |  Face Wash   |             3 |        15000 |         45000 |
# +--------------+---------------+--------------+---------------+
# Total Harga item sebesar Rp.339000
# Anda mendapatkan diskon sebesar 8%
# Total pembayaran sebesar Rp.311880
# Terima kasih sudah berbelanja
